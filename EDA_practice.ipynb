# %% [markdown]
# <a href="https://colab.research.google.com/github/yunju-1118/EWHA/blob/2025-1-Statistical-Methods-for-Big-Data-Analysis/EDA_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [Data Analysis] - EDA
#
# EDA 과정에서 파생변수를 만들고 grouping 해보기!:

# %% [markdown]
# 🧪 연습 데이터: sales_df

# %%
import pandas as pd

sales_df = pd.DataFrame({
    'customer_id': [101, 102, 103, 104, 105, 106],
    'region': ['North', 'South', 'North', 'East', 'East', 'South'],
    'product': ['A', 'B', 'A', 'B', 'A', 'B'],
    'price': [12000, 8000, 15000, 7000, 11000, 9500],
    'quantity': [2, 3, 1, 4, 2, 1]
})

# %% [markdown]
# ❓ 문제 1: 파생변수 생성
# price와 quantity를 이용하여 total_sales라는 파생변수를 만들고, sales_df에 추가하시오.
#
# 🔹 힌트: total_sales = price * quantity

# %%
sales_df['total_sales'] = sales_df['price'] * sales_df['quantity']
sales_df
# Out:
#    customer_id region product  price  quantity  total_sales
# 0          101  North       A  12000         2        24000
# 1          102  South       B   8000         3        24000
# 2          103  North       A  15000         1        15000
# 3          104   East       B   7000         4        28000
# 4          105   East       A  11000         2        22000
# 5          106  South       B   9500         1         9500

# %% [markdown]
# ❓ 문제 2: 조건 기반 파생변수 생성
# 고객의 total_sales가 25,000원 이상이면 'VIP',
# 15,000원 이상이면 'Regular',
# 그 이하는 'New'로 구분하는 customer_grade 열을 추가하시오.

# %%
def grade(x):
  if x >= 25000:
    return ' VIP'
  elif x>=15000:
    return 'Regular'
  else:
    return 'New'

sales_df['customer_grade'] = sales_df['total_sales'].apply(grade)

# %%
sales_df
# Out:
#    customer_id region product  price  quantity  total_sales customer_grade
# 0          101  North       A  12000         2        24000        Regular
# 1          102  South       B   8000         3        24000        Regular
# 2          103  North       A  15000         1        15000        Regular
# 3          104   East       B   7000         4        28000            VIP
# 4          105   East       A  11000         2        22000        Regular
# 5          106  South       B   9500         1         9500            New

# %% [markdown]
# ❓ 문제 3: 그룹화(GroupBy)
#
# 각 region별로 total_sales의 총합을 구하시오.
#
# 각 product별로 quantity의 평균을 구하시오.
#
# 각 customer_grade별로 고객 수(count)와 total_sales 평균을 구하시오.

# %% [markdown]
# region

# %%
sales_df.groupby('region')['total_sales'].sum()
# Out:
# region
# East     50000
# North    39000
# South    33500
# Name: total_sales, dtype: int64

# %% [markdown]
# product

# %%
sales_df.groupby('product')['quantity'].mean()
# Out:
# product
# A    1.666667
# B    2.666667
# Name: quantity, dtype: float64

# %% [markdown]
# customer_grade

# %%
sales_df.groupby('customer_grade').count()['customer_id']
# Out:
# customer_grade
#  VIP       1
# New        1
# Regular    4
# Name: customer_id, dtype: int64

# %%
sales_df.groupby('customer_grade')['total_sales'].mean()
# Out:
# customer_grade
#  VIP       28000.0
# New         9500.0
# Regular    21250.0
# Name: total_sales, dtype: float64

# %% [markdown]
# 📊 데이터: orders_df (가상의 온라인 쇼핑몰 주문 데이터)

# %%
import pandas as pd

orders_df = pd.DataFrame({
    'order_id': [1, 2, 3, 4, 5, 6, 7, 8],
    'customer_id': [101, 102, 101, 103, 104, 105, 104, 106],
    'product': ['A', 'B', 'A', 'C', 'A', 'B', 'C', 'B'],
    'order_date': ['2023-01-01', '2023-01-03', '2023-01-10', '2023-01-12',
                   '2023-01-20', '2023-01-25', '2023-01-28', '2023-01-30'],
    'price': [10000, 8000, 10000, 12000, 10000, 8000, 12000, 8000],
    'quantity': [1, 2, 3, 1, 2, 1, 2, 1]
})
orders_df['order_date'] = pd.to_datetime(orders_df['order_date'])  # 날짜형으로 변환

# %% [markdown]
# ❓ 문제 1: 파생변수 생성
# total_price = price * quantity라는 파생변수를 생성하고 orders_df에 추가하시오.

# %%
orders_df['total_price'] = orders_df['price']*orders_df['quantity']
orders_df
# Out:
#    order_id  customer_id product order_date  price  quantity  total_price
# 0         1          101       A 2023-01-01  10000         1        10000
# 1         2          102       B 2023-01-03   8000         2        16000
# 2         3          101       A 2023-01-10  10000         3        30000
# 3         4          103       C 2023-01-12  12000         1        12000
# 4         5          104       A 2023-01-20  10000         2        20000
# 5         6          105       B 2023-01-25   8000         1         8000
# 6         7          104       C 2023-01-28  12000         2        24000
# 7         8          106       B 2023-01-30   8000         1         8000

# %% [markdown]
# ❓ 문제 2: 고객별 누적 구매 금액
# customer_id별 total_price의 합계를 구하시오.
#
# 누적 구매금액이 30000 이상인 고객만 추출하시오.

# %%
orders_df.groupby('customer_id')[['total_price']].sum().query('total_price>=30000')
# Out:
#              total_price
# customer_id
# 101                40000
# 104                44000

# %% [markdown]
# ❓ 문제 3: 상품별 판매 수량 정렬
# product별 총 판매 수량(quantity)을 구하고, 판매 수량 기준으로 내림차순 정렬하시오.

# %%
orders_df.groupby('product')['quantity'].sum().sort_values(ascending=True)
# Out:
# product
# C    3
# B    4
# A    6
# Name: quantity, dtype: int64
